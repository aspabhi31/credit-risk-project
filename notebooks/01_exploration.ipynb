# %%
import pandas as pd

df = pd.read_csv(r"E:\Projects CanadaIndia Data Scientist\credit-risk-project\data\credit_data.csv")
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            150000 non-null  int64
#  1   SeriousDlqin2yrs                      150000 non-null  int64
#  2   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  3   age                                   150000 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  5   DebtRatio                             150000 non-null  float64
#  6   MonthlyIncome                         120269 non-null  float64
#  7   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  8   NumberOfTimes90DaysLate               150000 non-null  int64
#  9   NumberRealEstateLoansOrLines          150000 non-null  int64
# ...

# %%
# What column represents default? SeriousDlqin2yrs
# Roughly what % of customers default?

# %%
(len(df[df["SeriousDlqin2yrs"]==1])/len(df))*100
# Out:
# 6.683999999999999

# %%
# Only 6.68 % of data is defaulters
# Is the data imbalanced?
# Yes — the dataset is highly imbalanced.
# This is why: Accuracy is a bad metric. Metrics like ROC, KS, recall, and cutoff analysis matter more

# %%
df["RevolvingUtilizationOfUnsecuredLines"].value_counts()
# Out:
# RevolvingUtilizationOfUnsecuredLines
# 0.000000    10878
# 1.000000    10256
# 1.000000       17
# 0.950100        8
# 0.007984        6
#             ...
# 0.457101        1
# 0.293143        1
# 0.920107        1
# 1.005733        1
# 0.230353        1
# Name: count, Length: 125728, dtype: int64

# %%
# I can see one value 1.005733, ie, greater than 1 of RevolvingUtilizationOfUnsecuredLines
df["MonthlyIncome"].value_counts()
# Out:
# MonthlyIncome
# 5000.0     2757
# 4000.0     2106
# 6000.0     1934
# 3000.0     1758
# 0.0        1634
#            ...
# 7039.0        1
# 596.0         1
# 15648.0       1
# 521.0         1
# 15475.0       1
# Name: count, Length: 13594, dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                  0
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
df["DebtRatio"].value_counts()
# Out:
# DebtRatio
# 0.000000    4113
# 1.000000     229
# 4.000000     174
# 2.000000     170
# 3.000000     162
#             ...
# 0.073220       1
# 0.303432       1
# 0.386186       1
# 0.400547       1
# 0.209892       1
# Name: count, Length: 114194, dtype: int64

# %%
'''
Target Variable (Not a Feature)
SeriousDlqin2yrs → Default (1 = default, 0 = no default)

A. Behavioral / Credit History Features
MOST predictive in real-world credit risk
-RevolvingUtilizationOfUnsecuredLines
How much of available credit is being used
Extremely strong risk signal
-NumberOfTime30-59DaysPastDueNotWorse
History of short-term delinquency
Strong early-warning indicator
-NumberOfTime60-89DaysPastDueNotWorse
More severe delinquency behavior
-NumberOfTimes90DaysLate
Very strong default predictor
-NumberOfOpenCreditLinesAndLoans
Credit activity and exposure
-NumberRealEstateLoansOrLines
Type and size of credit exposure
-NumberOfDependents (weak behavioral)
Financial burden proxy

B. Demographic / Profile Features
-age
Risk tends to decrease with age (generally)
-MonthlyIncome
Ability to repay, but often noisy / missing
-DebtRatio
Important but often distorted by missing income

C. Special / “Watchlist” Features (Very Important)
These features are useful but suspicious and require care.
-MonthlyIncome
Many missing values
Zero or extreme values common
-DebtRatio
Can explode when income is low or missing
-RevolvingUtilizationOfUnsecuredLines
Values > 1 possible (over-limit behavior)
'''
# Out:
# '\nTarget Variable (Not a Feature)\nSeriousDlqin2yrs → Default (1 = default, 0 = no default)\n\nA. Behavioral / Credit History Features\nMOST predictive in real-world credit risk\n-RevolvingUtilizationOfUnsecuredLines\nHow much of available credit is being used\nExtremely strong risk signal\n-NumberOfTime30-59DaysPastDueNotWorse\nHistory of short-term delinquency\nStrong early-warning indicator\n-NumberOfTime60-89DaysPastDueNotWorse\nMore severe delinquency behavior\n-NumberOfTimes90DaysLate\nVery strong default predictor\n-NumberOfOpenCreditLinesAndLoans\nCredit activity and exposure\n-NumberRealEstateLoansOrLines\nType and size of credit exposure\n-NumberOfDependents (weak behavioral)\nFinancial burden proxy\n\nB. Demographic / Profile Features\n-age\nRisk tends to decrease with age (generally)\n-MonthlyIncome\nAbility to repay, but often noisy / missing\n-DebtRatio\nImportant but often distorted by missing income\n\nC. Special / “Watchlist” Features (Very Important)\nThese feature
# ...
